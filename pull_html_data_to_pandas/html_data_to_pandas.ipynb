# %%
import pandas as pd
import requests

# %%
url = "https://www.cricketworldcup.com/standings"

# %%
table = pd.read_html(url)

# %%
df = table[0]

# %%
df.head()
# Out:
#    Pos              Team  Played  PLD  Won  Lost  N/R   Tied  Net RR  NRR  \
# 0    1   New Zealand  NZ       4    4    0     0    0  1.923       8  NaN
# 1    2        India  IND       4    4    0     0    0  1.659       8  NaN
# 2    3  South Africa  SA       4    3    1     0    0  2.212       6  NaN
# 3    4    Australia  AUS       4    2    2     0    0 -0.193       4  NaN
# 4    5     Pakistan  PAK       4    2    2     0    0 -0.456       4  NaN
#
#    PointsPts
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
url1 = "https://datatables.net/extensions/searchbuilder/examples/initialisation/html.html"

# %%
response = requests.get(url1)

# %%
table1 = pd.read_html(response.text)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10328\2629036765.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   table1 = pd.read_html(response.text)

# %%
table1[0]
# Out:
#                    Name                       Position         Office  Age  \
# 0           Tiger Nixon               System Architect      Edinburgh   61
# 1       Garrett Winters                     Accountant          Tokyo   63
# 2            Ashton Cox        Junior Technical Author  San Francisco   66
# 3          Cedric Kelly    Senior Javascript Developer      Edinburgh   22
# 4            Airi Satou                     Accountant          Tokyo   33
# 5    Brielle Williamson         Integration Specialist       New York   61
# 6       Herrod Chandler                Sales Assistant  San Francisco   59
# 7        Rhona Davidson         Integration Specialist          Tokyo   55
# 8         Colleen Hurst           Javascript Developer  San Francisco   39
# 9           Sonya Frost              Software Engineer      Edinburgh   23
# 10          Jena Gaines                 Office Manager         London   30
# ...

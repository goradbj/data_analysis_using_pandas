# %%
 #!pip install pandas sqlalchemy

# %% [markdown]
# Import Packages

# %%
import configparser
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# Read config file

# %%
config = configparser.ConfigParser()
config.read("config.ini")
# Out:
# ['config.ini']

# %% [markdown]
# Read credentials

# %%
host = config['database']['host']
user = config['database']['user']
password = config['database']['password']
port = config['database']['port']
database_name = config['database']['database_name']

# %% [markdown]
# Create Database Connection

# %%
engine = create_engine(f'mysql+mysqlconnector://{user}:{password}@{host}:{port}/{database_name}')

# %% [markdown]
# Pull Data from Database

# %%
sql_query = "select * from crimes;"

# %%
df = pd.read_sql(sql_query, engine)

# %%
df
# Out:
#                       Area_Name  Crime_Year           Group_Name  \
# 0     Andaman & Nicobar Islands        2001  Burglary - Property
# 1                Andhra Pradesh        2001  Burglary - Property
# 2             Arunachal Pradesh        2001  Burglary - Property
# 3                         Assam        2001  Burglary - Property
# 4                         Bihar        2001  Burglary - Property
# ...                         ...         ...                  ...
# 2444                 Tamil Nadu        2010       Total Property
# 2445                    Tripura        2010       Total Property
# 2446              Uttar Pradesh        2010       Total Property
# 2447                Uttarakhand        2010       Total Property
# 2448                West Bengal        2010       Total Property
#
#                             Sub_Group_Name  Cases_Property_Recovered  \
# 0                              3. Burglary                        27
# 1                              3. Burglary                      3321
# 2                              3. Burglary                        66
# 3                              3. Burglary                       539
# 4                              3. Burglary                       367
# ...                                    ...                       ...
# 2444  7. Total Property Stolen & Recovered                     16125
# 2445  7. Total Property Stolen & Recovered                       192
# 2446  7. Total Property Stolen & Recovered                      9130
# 2447  7. Total Property Stolen & Recovered                       964
# 2448  7. Total Property Stolen & Recovered                      4548
#
#       Cases_Property_Stolen  Value_of_Property_Recovered  \
# 0                        64                       755858
# 1                      7134                     51483437
# 2                       248                       825115
# 3                      2423                      3722850
# 4                      3231                      2327135
# ...                     ...                          ...
# 2444                  21509                    660311804
# 2445                    879                      5666102
# 2446                  35068                    577591772
# 2447                   2234                     47135685
# 2448                  23759                   1168242161
#
#       Value_of_Property_Stolen
# 0                      1321961
# 1                    147019348
# 2                      4931904
# 3                     21466955
# 4                     17023937
# ...                        ...
# 2444                1317919190
# 2445                  33032746
# 2446                1442670414
# 2447                 123398840
# 2448                5015168687
#
# [2449 rows x 8 columns]

# %%
# df.to_csv("crime_data.csv")

# %% [markdown]
# Basic

# %% [markdown]
# Knowing number of rows and columns (shape)

# %%
df.shape
# Out:
# (2449, 8)

# %% [markdown]
# Display size of df

# %%
df.size
# Out:
# 19592

# %% [markdown]
# Retrieve top few records

# %%
df.head(3)
# Out:
#                    Area_Name  Crime_Year           Group_Name Sub_Group_Name  \
# 0  Andaman & Nicobar Islands        2001  Burglary - Property    3. Burglary
# 1             Andhra Pradesh        2001  Burglary - Property    3. Burglary
# 2          Arunachal Pradesh        2001  Burglary - Property    3. Burglary
#
#    Cases_Property_Recovered  Cases_Property_Stolen  \
# 0                        27                     64
# 1                      3321                   7134
# 2                        66                    248
#
#    Value_of_Property_Recovered  Value_of_Property_Stolen
# 0                       755858                   1321961
# 1                     51483437                 147019348
# 2                       825115                   4931904

# %% [markdown]
# Retrieve bottom few records

# %%
df.tail(2)
# Out:
#         Area_Name  Crime_Year      Group_Name  \
# 2447  Uttarakhand        2010  Total Property
# 2448  West Bengal        2010  Total Property
#
#                             Sub_Group_Name  Cases_Property_Recovered  \
# 2447  7. Total Property Stolen & Recovered                       964
# 2448  7. Total Property Stolen & Recovered                      4548
#
#       Cases_Property_Stolen  Value_of_Property_Recovered  \
# 2447                   2234                     47135685
# 2448                  23759                   1168242161
#
#       Value_of_Property_Stolen
# 2447                 123398840
# 2448                5015168687

# %% [markdown]
# Retrieve mid few records

# %%
df.head(100).tail(5)
# Out:
#      Area_Name  Crime_Year           Group_Name Sub_Group_Name  \
# 95      Odisha        2003  Burglary - Property    3. Burglary
# 96  Puducherry        2003  Burglary - Property    3. Burglary
# 97      Punjab        2003  Burglary - Property    3. Burglary
# 98   Rajasthan        2003  Burglary - Property    3. Burglary
# 99      Sikkim        2003  Burglary - Property    3. Burglary
#
#     Cases_Property_Recovered  Cases_Property_Stolen  \
# 95                      1231                   2910
# 96                        56                    126
# 97                       797                   2094
# 98                      1588                   5779
# 99                         7                     48
#
#     Value_of_Property_Recovered  Value_of_Property_Stolen
# 95                     13996401                  48730506
# 96                      1679750                   6744373
# 97                     19620531                  86923821
# 98                     50150183                 129565091
# 99                       318439                   1546492

# %%
df.tail(2354).head(5)
# Out:
#      Area_Name  Crime_Year           Group_Name Sub_Group_Name  \
# 95      Odisha        2003  Burglary - Property    3. Burglary
# 96  Puducherry        2003  Burglary - Property    3. Burglary
# 97      Punjab        2003  Burglary - Property    3. Burglary
# 98   Rajasthan        2003  Burglary - Property    3. Burglary
# 99      Sikkim        2003  Burglary - Property    3. Burglary
#
#     Cases_Property_Recovered  Cases_Property_Stolen  \
# 95                      1231                   2910
# 96                        56                    126
# 97                       797                   2094
# 98                      1588                   5779
# 99                         7                     48
#
#     Value_of_Property_Recovered  Value_of_Property_Stolen
# 95                     13996401                  48730506
# 96                      1679750                   6744373
# 97                     19620531                  86923821
# 98                     50150183                 129565091
# 99                       318439                   1546492

# %% [markdown]
# Display Columns in df

# %%
df.columns
# Out:
# Index(['Area_Name', 'Crime_Year', 'Group_Name', 'Sub_Group_Name',
#        'Cases_Property_Recovered', 'Cases_Property_Stolen',
#        'Value_of_Property_Recovered', 'Value_of_Property_Stolen'],
#       dtype='object')

# %% [markdown]
# Display Basic Info of df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2449 entries, 0 to 2448
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Area_Name                    2449 non-null   object
#  1   Crime_Year                   2449 non-null   int64
#  2   Group_Name                   2449 non-null   object
#  3   Sub_Group_Name               2449 non-null   object
#  4   Cases_Property_Recovered     2449 non-null   int64
#  5   Cases_Property_Stolen        2449 non-null   int64
#  6   Value_of_Property_Recovered  2449 non-null   int64
#  7   Value_of_Property_Stolen     2449 non-null   int64
# dtypes: int64(5), object(3)
# memory usage: 153.2+ KB

# %% [markdown]
# Retrieve data of specific column

# %%
df[['Value_of_Property_Stolen']]
# Out:
#       Value_of_Property_Stolen
# 0                      1321961
# 1                    147019348
# 2                      4931904
# 3                     21466955
# 4                     17023937
# ...                        ...
# 2444                1317919190
# 2445                  33032746
# 2446                1442670414
# 2447                 123398840
# 2448                5015168687
#
# [2449 rows x 1 columns]

# %%
df.Value_of_Property_Stolen
# Out:
# 0          1321961
# 1        147019348
# 2          4931904
# 3         21466955
# 4         17023937
#            ...
# 2444    1317919190
# 2445      33032746
# 2446    1442670414
# 2447     123398840
# 2448    5015168687
# Name: Value_of_Property_Stolen, Length: 2449, dtype: int64

# %% [markdown]
# Unique Values in column

# %%
df.Area_Name.unique()
# Out:
# array(['Andaman & Nicobar Islands', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra & Nagar Haveli', 'Daman & Diu', 'Delhi', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Lakshadweep', 'Madhya Pradesh',
#        'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland',
#        'Odisha', 'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
#        'West Bengal'], dtype=object)

# %% [markdown]
# No of unique values in column

# %%
df.Area_Name.nunique()
# Out:
# 35

# %% [markdown]
# count of each value in columns

# %%
df.Area_Name.value_counts()
# Out:
# Area_Name
# Andaman & Nicobar Islands    70
# Puducherry                   70
# Maharashtra                  70
# Manipur                      70
# Meghalaya                    70
# Mizoram                      70
# Nagaland                     70
# Odisha                       70
# Punjab                       70
# Andhra Pradesh               70
# Rajasthan                    70
# Sikkim                       70
# Tamil Nadu                   70
# Tripura                      70
# Uttar Pradesh                70
# Uttarakhand                  70
# Madhya Pradesh               70
# Kerala                       70
# Delhi                        70
# Daman & Diu                  70
# Arunachal Pradesh            70
# Assam                        70
# Bihar                        70
# Chandigarh                   70
# Chhattisgarh                 70
# Dadra & Nagar Haveli         70
# West Bengal                  70
# Karnataka                    70
# Goa                          70
# Gujarat                      70
# Haryana                      70
# Himachal Pradesh             70
# Jammu & Kashmir              70
# Jharkhand                    70
# Lakshadweep                  69
# Name: count, dtype: int64

# %% [markdown]
# Retrieve data of multiple columns

# %%
df[['Area_Name','Crime_Year','Value_of_Property_Stolen']]
# Out:
#                       Area_Name  Crime_Year  Value_of_Property_Stolen
# 0     Andaman & Nicobar Islands        2001                   1321961
# 1                Andhra Pradesh        2001                 147019348
# 2             Arunachal Pradesh        2001                   4931904
# 3                         Assam        2001                  21466955
# 4                         Bihar        2001                  17023937
# ...                         ...         ...                       ...
# 2444                 Tamil Nadu        2010                1317919190
# 2445                    Tripura        2010                  33032746
# 2446              Uttar Pradesh        2010                1442670414
# 2447                Uttarakhand        2010                 123398840
# 2448                West Bengal        2010                5015168687
#
# [2449 rows x 3 columns]

# %% [markdown]
# Finding min value of column

# %%
df.Crime_Year.min()
# Out:
# 2001

# %% [markdown]
# Find max value of column

# %%
df.Crime_Year.max()
# Out:
# 2010

# %% [markdown]
# Display Statistical Information of df

# %%
df.describe()
# Out:
#         Crime_Year  Cases_Property_Recovered  Cases_Property_Stolen  \
# count  2449.000000               2449.000000            2449.000000
# mean   2005.499388               1232.892201            3419.420988
# std       2.873294               3079.573907            8136.256820
# min    2001.000000                  0.000000               0.000000
# 25%    2003.000000                 13.000000              45.000000
# 50%    2005.000000                113.000000             358.000000
# 75%    2008.000000                722.000000            1875.000000
# max    2010.000000              27960.000000           80663.000000
#
#        Value_of_Property_Recovered  Value_of_Property_Stolen
# count                 2.449000e+03              2.449000e+03
# mean                  5.859924e+07              2.465431e+08
# std                   2.494403e+08              9.670035e+08
# min                   0.000000e+00              0.000000e+00
# 25%                   6.845700e+05              3.649018e+06
# 50%                   5.851830e+06              2.701800e+07
# 75%                   3.406395e+07              1.214580e+08
# max                   7.470011e+09              2.377625e+10

# %% [markdown]
# Know the Index of data

# %%
df
# Out:
#                       Area_Name  Crime_Year           Group_Name  \
# 0     Andaman & Nicobar Islands        2001  Burglary - Property
# 1                Andhra Pradesh        2001  Burglary - Property
# 2             Arunachal Pradesh        2001  Burglary - Property
# 3                         Assam        2001  Burglary - Property
# 4                         Bihar        2001  Burglary - Property
# ...                         ...         ...                  ...
# 2444                 Tamil Nadu        2010       Total Property
# 2445                    Tripura        2010       Total Property
# 2446              Uttar Pradesh        2010       Total Property
# 2447                Uttarakhand        2010       Total Property
# 2448                West Bengal        2010       Total Property
#
#                             Sub_Group_Name  Cases_Property_Recovered  \
# 0                              3. Burglary                        27
# 1                              3. Burglary                      3321
# 2                              3. Burglary                        66
# 3                              3. Burglary                       539
# 4                              3. Burglary                       367
# ...                                    ...                       ...
# 2444  7. Total Property Stolen & Recovered                     16125
# 2445  7. Total Property Stolen & Recovered                       192
# 2446  7. Total Property Stolen & Recovered                      9130
# 2447  7. Total Property Stolen & Recovered                       964
# 2448  7. Total Property Stolen & Recovered                      4548
#
#       Cases_Property_Stolen  Value_of_Property_Recovered  \
# 0                        64                       755858
# 1                      7134                     51483437
# 2                       248                       825115
# 3                      2423                      3722850
# 4                      3231                      2327135
# ...                     ...                          ...
# 2444                  21509                    660311804
# 2445                    879                      5666102
# 2446                  35068                    577591772
# 2447                   2234                     47135685
# 2448                  23759                   1168242161
#
#       Value_of_Property_Stolen
# 0                      1321961
# 1                    147019348
# 2                      4931904
# 3                     21466955
# 4                     17023937
# ...                        ...
# 2444                1317919190
# 2445                  33032746
# 2446                1442670414
# 2447                 123398840
# 2448                5015168687
#
# [2449 rows x 8 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2449, step=1)

# %% [markdown]
# Setting column as index

# %%
df.set_index("Crime_Year", inplace=True)
df
# Out:
#                             Area_Name           Group_Name  \
# Crime_Year
# 2001        Andaman & Nicobar Islands  Burglary - Property
# 2001                   Andhra Pradesh  Burglary - Property
# 2001                Arunachal Pradesh  Burglary - Property
# 2001                            Assam  Burglary - Property
# 2001                            Bihar  Burglary - Property
# ...                               ...                  ...
# 2010                       Tamil Nadu       Total Property
# 2010                          Tripura       Total Property
# 2010                    Uttar Pradesh       Total Property
# 2010                      Uttarakhand       Total Property
# 2010                      West Bengal       Total Property
#
#                                   Sub_Group_Name  Cases_Property_Recovered  \
# Crime_Year
# 2001                                 3. Burglary                        27
# 2001                                 3. Burglary                      3321
# 2001                                 3. Burglary                        66
# 2001                                 3. Burglary                       539
# 2001                                 3. Burglary                       367
# ...                                          ...                       ...
# 2010        7. Total Property Stolen & Recovered                     16125
# 2010        7. Total Property Stolen & Recovered                       192
# 2010        7. Total Property Stolen & Recovered                      9130
# 2010        7. Total Property Stolen & Recovered                       964
# 2010        7. Total Property Stolen & Recovered                      4548
#
#             Cases_Property_Stolen  Value_of_Property_Recovered  \
# Crime_Year
# 2001                           64                       755858
# 2001                         7134                     51483437
# 2001                          248                       825115
# 2001                         2423                      3722850
# 2001                         3231                      2327135
# ...                           ...                          ...
# 2010                        21509                    660311804
# 2010                          879                      5666102
# 2010                        35068                    577591772
# 2010                         2234                     47135685
# 2010                        23759                   1168242161
#
#             Value_of_Property_Stolen
# Crime_Year
# 2001                         1321961
# 2001                       147019348
# 2001                         4931904
# 2001                        21466955
# 2001                        17023937
# ...                              ...
# 2010                      1317919190
# 2010                        33032746
# 2010                      1442670414
# 2010                       123398840
# 2010                      5015168687
#
# [2449 rows x 7 columns]

# %% [markdown]
# Resetting index of df

# %%
df.reset_index(inplace=True)
df
# Out:
#       Crime_Year                  Area_Name           Group_Name  \
# 0           2001  Andaman & Nicobar Islands  Burglary - Property
# 1           2001             Andhra Pradesh  Burglary - Property
# 2           2001          Arunachal Pradesh  Burglary - Property
# 3           2001                      Assam  Burglary - Property
# 4           2001                      Bihar  Burglary - Property
# ...          ...                        ...                  ...
# 2444        2010                 Tamil Nadu       Total Property
# 2445        2010                    Tripura       Total Property
# 2446        2010              Uttar Pradesh       Total Property
# 2447        2010                Uttarakhand       Total Property
# 2448        2010                West Bengal       Total Property
#
#                             Sub_Group_Name  Cases_Property_Recovered  \
# 0                              3. Burglary                        27
# 1                              3. Burglary                      3321
# 2                              3. Burglary                        66
# 3                              3. Burglary                       539
# 4                              3. Burglary                       367
# ...                                    ...                       ...
# 2444  7. Total Property Stolen & Recovered                     16125
# 2445  7. Total Property Stolen & Recovered                       192
# 2446  7. Total Property Stolen & Recovered                      9130
# 2447  7. Total Property Stolen & Recovered                       964
# 2448  7. Total Property Stolen & Recovered                      4548
#
#       Cases_Property_Stolen  Value_of_Property_Recovered  \
# 0                        64                       755858
# 1                      7134                     51483437
# 2                       248                       825115
# 3                      2423                      3722850
# 4                      3231                      2327135
# ...                     ...                          ...
# 2444                  21509                    660311804
# 2445                    879                      5666102
# 2446                  35068                    577591772
# 2447                   2234                     47135685
# 2448                  23759                   1168242161
#
#       Value_of_Property_Stolen
# 0                      1321961
# 1                    147019348
# 2                      4931904
# 3                     21466955
# 4                     17023937
# ...                        ...
# 2444                1317919190
# 2445                  33032746
# 2446                1442670414
# 2447                 123398840
# 2448                5015168687
#
# [2449 rows x 8 columns]

# %% [markdown]
# Retrieve Range of rows

# %%
df[200:220]
# Out:
#      Crime_Year                  Area_Name           Group_Name  \
# 200        2006                     Odisha  Burglary - Property
# 201        2006                 Puducherry  Burglary - Property
# 202        2006                     Punjab  Burglary - Property
# 203        2006                  Rajasthan  Burglary - Property
# 204        2006                     Sikkim  Burglary - Property
# 205        2006                 Tamil Nadu  Burglary - Property
# 206        2006                    Tripura  Burglary - Property
# 207        2006              Uttar Pradesh  Burglary - Property
# 208        2006                Uttarakhand  Burglary - Property
# 209        2006                West Bengal  Burglary - Property
# 210        2007  Andaman & Nicobar Islands  Burglary - Property
# 211        2007             Andhra Pradesh  Burglary - Property
# 212        2007          Arunachal Pradesh  Burglary - Property
# 213        2007                      Assam  Burglary - Property
# 214        2007                      Bihar  Burglary - Property
# 215        2007                 Chandigarh  Burglary - Property
# 216        2007               Chhattisgarh  Burglary - Property
# 217        2007       Dadra & Nagar Haveli  Burglary - Property
# 218        2007                Daman & Diu  Burglary - Property
# 219        2007                      Delhi  Burglary - Property
#
#     Sub_Group_Name  Cases_Property_Recovered  Cases_Property_Stolen  \
# 200    3. Burglary                      1425                   3118
# 201    3. Burglary                        46                     84
# 202    3. Burglary                       955                   2277
# 203    3. Burglary                      1678                   4879
# 204    3. Burglary                        13                     84
# 205    3. Burglary                      2291                   3300
# 206    3. Burglary                       115                    182
# 207    3. Burglary                       880                   3545
# 208    3. Burglary                       114                    410
# 209    3. Burglary                       138                    601
# 210    3. Burglary                        21                     90
# 211    3. Burglary                      3827                   7609
# 212    3. Burglary                        90                    240
# 213    3. Burglary                       491                   2603
# 214    3. Burglary                       294                   3259
# 215    3. Burglary                        63                    191
# 216    3. Burglary                      1164                   3632
# 217    3. Burglary                         6                     28
# 218    3. Burglary                         4                     46
# 219    3. Burglary                       981                   2055
#
#      Value_of_Property_Recovered  Value_of_Property_Stolen
# 200                     17798514                  84174508
# 201                      1104955                   2477094
# 202                     25846606                 115272477
# 203                     51924184                 136663767
# 204                       100500                   2703436
# 205                     79307801                 125033409
# 206                      2210714                   4891139
# 207                    119979317                 231897742
# 208                      4488841                  14234550
# 209                      3981448                  13223258
# 210                       715116                   3173066
# 211                     85999945                 265927102
# 212                      4211030                  11311656
# 213                      5730761                  36285212
# 214                      3910175                  56610107
# 215                      2197700                   8182250
# 216                     11248886                  52170119
# 217                       684570                   5444419
# 218                      1918200                  10058460
# 219                      8374449                 142856412

# %% [markdown]
# Retrieve range of rows with specific columns

# %%
df[200:220][['Area_Name','Group_Name']]
# Out:
#                      Area_Name           Group_Name
# 200                     Odisha  Burglary - Property
# 201                 Puducherry  Burglary - Property
# 202                     Punjab  Burglary - Property
# 203                  Rajasthan  Burglary - Property
# 204                     Sikkim  Burglary - Property
# 205                 Tamil Nadu  Burglary - Property
# 206                    Tripura  Burglary - Property
# 207              Uttar Pradesh  Burglary - Property
# 208                Uttarakhand  Burglary - Property
# 209                West Bengal  Burglary - Property
# 210  Andaman & Nicobar Islands  Burglary - Property
# 211             Andhra Pradesh  Burglary - Property
# 212          Arunachal Pradesh  Burglary - Property
# 213                      Assam  Burglary - Property
# 214                      Bihar  Burglary - Property
# 215                 Chandigarh  Burglary - Property
# 216               Chhattisgarh  Burglary - Property
# 217       Dadra & Nagar Haveli  Burglary - Property
# 218                Daman & Diu  Burglary - Property
# 219                      Delhi  Burglary - Property

# %% [markdown]
# Viewing df using loc()

# %%
# all rows and all columns
df.loc[:,:]
# Out:
#       Crime_Year                  Area_Name           Group_Name  \
# 0           2001  Andaman & Nicobar Islands  Burglary - Property
# 1           2001             Andhra Pradesh  Burglary - Property
# 2           2001          Arunachal Pradesh  Burglary - Property
# 3           2001                      Assam  Burglary - Property
# 4           2001                      Bihar  Burglary - Property
# ...          ...                        ...                  ...
# 2444        2010                 Tamil Nadu       Total Property
# 2445        2010                    Tripura       Total Property
# 2446        2010              Uttar Pradesh       Total Property
# 2447        2010                Uttarakhand       Total Property
# 2448        2010                West Bengal       Total Property
#
#                             Sub_Group_Name  Cases_Property_Recovered  \
# 0                              3. Burglary                        27
# 1                              3. Burglary                      3321
# 2                              3. Burglary                        66
# 3                              3. Burglary                       539
# 4                              3. Burglary                       367
# ...                                    ...                       ...
# 2444  7. Total Property Stolen & Recovered                     16125
# 2445  7. Total Property Stolen & Recovered                       192
# 2446  7. Total Property Stolen & Recovered                      9130
# 2447  7. Total Property Stolen & Recovered                       964
# 2448  7. Total Property Stolen & Recovered                      4548
#
#       Cases_Property_Stolen  Value_of_Property_Recovered  \
# 0                        64                       755858
# 1                      7134                     51483437
# 2                       248                       825115
# 3                      2423                      3722850
# 4                      3231                      2327135
# ...                     ...                          ...
# 2444                  21509                    660311804
# 2445                    879                      5666102
# 2446                  35068                    577591772
# 2447                   2234                     47135685
# 2448                  23759                   1168242161
#
#       Value_of_Property_Stolen
# 0                      1321961
# 1                    147019348
# 2                      4931904
# 3                     21466955
# 4                     17023937
# ...                        ...
# 2444                1317919190
# 2445                  33032746
# 2446                1442670414
# 2447                 123398840
# 2448                5015168687
#
# [2449 rows x 8 columns]

# %%
# first 100 rows and all columns
df.loc[:100,:]
# Out:
#      Crime_Year                  Area_Name           Group_Name  \
# 0          2001  Andaman & Nicobar Islands  Burglary - Property
# 1          2001             Andhra Pradesh  Burglary - Property
# 2          2001          Arunachal Pradesh  Burglary - Property
# 3          2001                      Assam  Burglary - Property
# 4          2001                      Bihar  Burglary - Property
# ..          ...                        ...                  ...
# 96         2003                 Puducherry  Burglary - Property
# 97         2003                     Punjab  Burglary - Property
# 98         2003                  Rajasthan  Burglary - Property
# 99         2003                     Sikkim  Burglary - Property
# 100        2003                 Tamil Nadu  Burglary - Property
#
#     Sub_Group_Name  Cases_Property_Recovered  Cases_Property_Stolen  \
# 0      3. Burglary                        27                     64
# 1      3. Burglary                      3321                   7134
# 2      3. Burglary                        66                    248
# 3      3. Burglary                       539                   2423
# 4      3. Burglary                       367                   3231
# ..             ...                       ...                    ...
# 96     3. Burglary                        56                    126
# 97     3. Burglary                       797                   2094
# 98     3. Burglary                      1588                   5779
# 99     3. Burglary                         7                     48
# 100    3. Burglary                      2877                   4849
#
#      Value_of_Property_Recovered  Value_of_Property_Stolen
# 0                         755858                   1321961
# 1                       51483437                 147019348
# 2                         825115                   4931904
# 3                        3722850                  21466955
# 4                        2327135                  17023937
# ..                           ...                       ...
# 96                       1679750                   6744373
# 97                      19620531                  86923821
# 98                      50150183                 129565091
# 99                        318439                   1546492
# 100                     55816582                 111017636
#
# [101 rows x 8 columns]

# %%
# 95 to 100 rows and all columns
df.loc[95:100,:]
# Out:
#      Crime_Year   Area_Name           Group_Name Sub_Group_Name  \
# 95         2003      Odisha  Burglary - Property    3. Burglary
# 96         2003  Puducherry  Burglary - Property    3. Burglary
# 97         2003      Punjab  Burglary - Property    3. Burglary
# 98         2003   Rajasthan  Burglary - Property    3. Burglary
# 99         2003      Sikkim  Burglary - Property    3. Burglary
# 100        2003  Tamil Nadu  Burglary - Property    3. Burglary
#
#      Cases_Property_Recovered  Cases_Property_Stolen  \
# 95                       1231                   2910
# 96                         56                    126
# 97                        797                   2094
# 98                       1588                   5779
# 99                          7                     48
# 100                      2877                   4849
#
#      Value_of_Property_Recovered  Value_of_Property_Stolen
# 95                      13996401                  48730506
# 96                       1679750                   6744373
# 97                      19620531                  86923821
# 98                      50150183                 129565091
# 99                        318439                   1546492
# 100                     55816582                 111017636

# %%
# 95 to 100 rows and specific column
df.loc[95:100,['Area_Name']]
# Out:
#       Area_Name
# 95       Odisha
# 96   Puducherry
# 97       Punjab
# 98    Rajasthan
# 99       Sikkim
# 100  Tamil Nadu

# %%
# 95 to 100 rows and multiple columns
df.loc[95:100,['Area_Name','Crime_Year']]
# Out:
#       Area_Name  Crime_Year
# 95       Odisha        2003
# 96   Puducherry        2003
# 97       Punjab        2003
# 98    Rajasthan        2003
# 99       Sikkim        2003
# 100  Tamil Nadu        2003

# %% [markdown]
# Viewing df using iloc()

# %%
# 95 to 100 rows and specific column
df.iloc[95:100,[1]]
# Out:
#      Area_Name
# 95      Odisha
# 96  Puducherry
# 97      Punjab
# 98   Rajasthan
# 99      Sikkim

# %%
# 95 to 100 rows and multiple columns
df.iloc[95:100,[1,4]]
# Out:
#      Area_Name  Cases_Property_Recovered
# 95      Odisha                      1231
# 96  Puducherry                        56
# 97      Punjab                       797
# 98   Rajasthan                      1588
# 99      Sikkim                         7

# %%
# 95 to 100 rows and multiple columns with negative indexing
df.iloc[95:100,[-1, -2]]
# Out:
#     Value_of_Property_Stolen  Value_of_Property_Recovered
# 95                  48730506                     13996401
# 96                   6744373                      1679750
# 97                  86923821                     19620531
# 98                 129565091                     50150183
# 99                   1546492                       318439

# %% [markdown]
# Data Analysis Part - 2

# %%
df
# Out:
#       Crime_Year                  Area_Name           Group_Name  \
# 0           2001  Andaman & Nicobar Islands  Burglary - Property
# 1           2001             Andhra Pradesh  Burglary - Property
# 2           2001          Arunachal Pradesh  Burglary - Property
# 3           2001                      Assam  Burglary - Property
# 4           2001                      Bihar  Burglary - Property
# ...          ...                        ...                  ...
# 2444        2010                 Tamil Nadu       Total Property
# 2445        2010                    Tripura       Total Property
# 2446        2010              Uttar Pradesh       Total Property
# 2447        2010                Uttarakhand       Total Property
# 2448        2010                West Bengal       Total Property
#
#                             Sub_Group_Name  Cases_Property_Recovered  \
# 0                              3. Burglary                        27
# 1                              3. Burglary                      3321
# 2                              3. Burglary                        66
# 3                              3. Burglary                       539
# 4                              3. Burglary                       367
# ...                                    ...                       ...
# 2444  7. Total Property Stolen & Recovered                     16125
# 2445  7. Total Property Stolen & Recovered                       192
# 2446  7. Total Property Stolen & Recovered                      9130
# 2447  7. Total Property Stolen & Recovered                       964
# 2448  7. Total Property Stolen & Recovered                      4548
#
#       Cases_Property_Stolen  Value_of_Property_Recovered  \
# 0                        64                       755858
# 1                      7134                     51483437
# 2                       248                       825115
# 3                      2423                      3722850
# 4                      3231                      2327135
# ...                     ...                          ...
# 2444                  21509                    660311804
# 2445                    879                      5666102
# 2446                  35068                    577591772
# 2447                   2234                     47135685
# 2448                  23759                   1168242161
#
#       Value_of_Property_Stolen
# 0                      1321961
# 1                    147019348
# 2                      4931904
# 3                     21466955
# 4                     17023937
# ...                        ...
# 2444                1317919190
# 2445                  33032746
# 2446                1442670414
# 2447                 123398840
# 2448                5015168687
#
# [2449 rows x 8 columns]

# %% [markdown]
# Sort the dataframe

# %%
# using single column
df.sort_values(by='Cases_Property_Stolen')
# Out:
#       Crime_Year                  Area_Name               Group_Name  \
# 1359        2009                     Sikkim  Other heads of Property
# 1068        2001                Lakshadweep  Other heads of Property
# 1652        2008       Dadra & Nagar Haveli       Robbery - Property
# 1338        2009                Daman & Diu  Other heads of Property
# 1330        2009  Andaman & Nicobar Islands  Other heads of Property
# ...          ...                        ...                      ...
# 2260        2005                Maharashtra           Total Property
# 2329        2007                Maharashtra           Total Property
# 2399        2009                Maharashtra           Total Property
# 2364        2008                Maharashtra           Total Property
# 2434        2010                Maharashtra           Total Property
#
#                             Sub_Group_Name  Cases_Property_Recovered  \
# 1359                     6. Other Property                         0
# 1068                     6. Other Property                         0
# 1652                            2. Robbery                         0
# 1338                     6. Other Property                         0
# 1330                     6. Other Property                         0
# ...                                    ...                       ...
# 2260  7. Total Property Stolen & Recovered                     23704
# 2329  7. Total Property Stolen & Recovered                     25106
# 2399  7. Total Property Stolen & Recovered                     26097
# 2364  7. Total Property Stolen & Recovered                     26935
# 2434  7. Total Property Stolen & Recovered                     27960
#
#       Cases_Property_Stolen  Value_of_Property_Recovered  \
# 1359                      0                            0
# 1068                      0                            0
# 1652                      0                            0
# 1338                      0                            0
# 1330                      0                            0
# ...                     ...                          ...
# 2260                  70162                    885513709
# 2329                  71909                   1462054517
# 2399                  77240                   1352937107
# 2364                  78569                   1344884834
# 2434                  80663                   2337827896
#
#       Value_of_Property_Stolen
# 1359                         0
# 1068                         0
# 1652                         0
# 1338                         0
# 1330                         0
# ...                        ...
# 2260                6472818409
# 2329               10224489784
# 2399               12613758173
# 2364               15469344396
# 2434               23776254525
#
# [2449 rows x 8 columns]

# %%
# using single column descending
df.sort_values(by='Cases_Property_Stolen', ascending=False)
# Out:
#       Crime_Year                  Area_Name               Group_Name  \
# 2434        2010                Maharashtra           Total Property
# 2364        2008                Maharashtra           Total Property
# 2399        2009                Maharashtra           Total Property
# 2329        2007                Maharashtra           Total Property
# 2260        2005                Maharashtra           Total Property
# ...          ...                        ...                      ...
# 1138        2003                Lakshadweep  Other heads of Property
# 1134        2003            Jammu & Kashmir  Other heads of Property
# 1120        2003  Andaman & Nicobar Islands  Other heads of Property
# 1118        2002                Uttarakhand  Other heads of Property
# 1663        2008                Lakshadweep       Robbery - Property
#
#                             Sub_Group_Name  Cases_Property_Recovered  \
# 2434  7. Total Property Stolen & Recovered                     27960
# 2364  7. Total Property Stolen & Recovered                     26935
# 2399  7. Total Property Stolen & Recovered                     26097
# 2329  7. Total Property Stolen & Recovered                     25106
# 2260  7. Total Property Stolen & Recovered                     23704
# ...                                    ...                       ...
# 1138                     6. Other Property                         0
# 1134                     6. Other Property                         0
# 1120                     6. Other Property                         0
# 1118                     6. Other Property                         0
# 1663                            2. Robbery                         0
#
#       Cases_Property_Stolen  Value_of_Property_Recovered  \
# 2434                  80663                   2337827896
# 2364                  78569                   1344884834
# 2399                  77240                   1352937107
# 2329                  71909                   1462054517
# 2260                  70162                    885513709
# ...                     ...                          ...
# 1138                      0                            0
# 1134                      0                            0
# 1120                      0                            0
# 1118                      0                            0
# 1663                      0                            0
#
#       Value_of_Property_Stolen
# 2434               23776254525
# 2364               15469344396
# 2399               12613758173
# 2329               10224489784
# 2260                6472818409
# ...                        ...
# 1138                         0
# 1134                         0
# 1120                         0
# 1118                         0
# 1663                         0
#
# [2449 rows x 8 columns]

# %%
# using multiple columns
df.sort_values(by=['Crime_Year','Cases_Property_Stolen'], ascending=[False, False])
# Out:
#       Crime_Year        Area_Name               Group_Name  \
# 2434        2010      Maharashtra           Total Property
# 2085        2010      Maharashtra         Theft - Property
# 2415        2010   Andhra Pradesh           Total Property
# 2446        2010    Uttar Pradesh           Total Property
# 2433        2010   Madhya Pradesh           Total Property
# ...          ...              ...                      ...
# 1064        2001  Jammu & Kashmir  Other heads of Property
# 1068        2001      Lakshadweep  Other heads of Property
# 1083        2001      Uttarakhand  Other heads of Property
# 1408        2001      Daman & Diu       Robbery - Property
# 1418        2001      Lakshadweep       Robbery - Property
#
#                             Sub_Group_Name  Cases_Property_Recovered  \
# 2434  7. Total Property Stolen & Recovered                     27960
# 2085                              4. Theft                     16765
# 2415  7. Total Property Stolen & Recovered                     19848
# 2446  7. Total Property Stolen & Recovered                      9130
# 2433  7. Total Property Stolen & Recovered                     11549
# ...                                    ...                       ...
# 1064                     6. Other Property                         0
# 1068                     6. Other Property                         0
# 1083                     6. Other Property                         0
# 1408                            2. Robbery                         0
# 1418                            2. Robbery                         0
#
#       Cases_Property_Stolen  Value_of_Property_Recovered  \
# 2434                  80663                   2337827896
# 2085                  52363                    958264429
# 2415                  36407                    725079668
# 2446                  35068                    577591772
# 2433                  34358                   7470011363
# ...                     ...                          ...
# 1064                      0                            0
# 1068                      0                            0
# 1083                      0                            0
# 1408                      0                            0
# 1418                      0                            0
#
#       Value_of_Property_Stolen
# 2434               23776254525
# 2085                3640776890
# 2415                1533054566
# 2446                1442670414
# 2433                8265789122
# ...                        ...
# 1064                         0
# 1068                         0
# 1083                         0
# 1408                         0
# 1418                         0
#
# [2449 rows x 8 columns]

# %%
# sort based on multiple columns for few df columns
df[['Crime_Year','Area_Name','Cases_Property_Stolen']].sort_values(by=['Crime_Year','Cases_Property_Stolen'], ascending=[False, False]).reset_index(drop=True)
# Out:
#       Crime_Year        Area_Name  Cases_Property_Stolen
# 0           2010      Maharashtra                  80663
# 1           2010      Maharashtra                  52363
# 2           2010   Andhra Pradesh                  36407
# 3           2010    Uttar Pradesh                  35068
# 4           2010   Madhya Pradesh                  34358
# ...          ...              ...                    ...
# 2444        2001  Jammu & Kashmir                      0
# 2445        2001      Lakshadweep                      0
# 2446        2001      Uttarakhand                      0
# 2447        2001      Daman & Diu                      0
# 2448        2001      Lakshadweep                      0
#
# [2449 rows x 3 columns]

# %%
# sort based on index
df.sort_index()
# Out:
#       Crime_Year                  Area_Name           Group_Name  \
# 0           2001  Andaman & Nicobar Islands  Burglary - Property
# 1           2001             Andhra Pradesh  Burglary - Property
# 2           2001          Arunachal Pradesh  Burglary - Property
# 3           2001                      Assam  Burglary - Property
# 4           2001                      Bihar  Burglary - Property
# ...          ...                        ...                  ...
# 2444        2010                 Tamil Nadu       Total Property
# 2445        2010                    Tripura       Total Property
# 2446        2010              Uttar Pradesh       Total Property
# 2447        2010                Uttarakhand       Total Property
# 2448        2010                West Bengal       Total Property
#
#                             Sub_Group_Name  Cases_Property_Recovered  \
# 0                              3. Burglary                        27
# 1                              3. Burglary                      3321
# 2                              3. Burglary                        66
# 3                              3. Burglary                       539
# 4                              3. Burglary                       367
# ...                                    ...                       ...
# 2444  7. Total Property Stolen & Recovered                     16125
# 2445  7. Total Property Stolen & Recovered                       192
# 2446  7. Total Property Stolen & Recovered                      9130
# 2447  7. Total Property Stolen & Recovered                       964
# 2448  7. Total Property Stolen & Recovered                      4548
#
#       Cases_Property_Stolen  Value_of_Property_Recovered  \
# 0                        64                       755858
# 1                      7134                     51483437
# 2                       248                       825115
# 3                      2423                      3722850
# 4                      3231                      2327135
# ...                     ...                          ...
# 2444                  21509                    660311804
# 2445                    879                      5666102
# 2446                  35068                    577591772
# 2447                   2234                     47135685
# 2448                  23759                   1168242161
#
#       Value_of_Property_Stolen
# 0                      1321961
# 1                    147019348
# 2                      4931904
# 3                     21466955
# 4                     17023937
# ...                        ...
# 2444                1317919190
# 2445                  33032746
# 2446                1442670414
# 2447                 123398840
# 2448                5015168687
#
# [2449 rows x 8 columns]

# %%
# nlargest() Method
df.nlargest(5, 'Cases_Property_Stolen')
# Out:
#       Crime_Year    Area_Name      Group_Name  \
# 2434        2010  Maharashtra  Total Property
# 2364        2008  Maharashtra  Total Property
# 2399        2009  Maharashtra  Total Property
# 2329        2007  Maharashtra  Total Property
# 2260        2005  Maharashtra  Total Property
#
#                             Sub_Group_Name  Cases_Property_Recovered  \
# 2434  7. Total Property Stolen & Recovered                     27960
# 2364  7. Total Property Stolen & Recovered                     26935
# 2399  7. Total Property Stolen & Recovered                     26097
# 2329  7. Total Property Stolen & Recovered                     25106
# 2260  7. Total Property Stolen & Recovered                     23704
#
#       Cases_Property_Stolen  Value_of_Property_Recovered  \
# 2434                  80663                   2337827896
# 2364                  78569                   1344884834
# 2399                  77240                   1352937107
# 2329                  71909                   1462054517
# 2260                  70162                    885513709
#
#       Value_of_Property_Stolen
# 2434               23776254525
# 2364               15469344396
# 2399               12613758173
# 2329               10224489784
# 2260                6472818409

# %%
# nsmallest() Methods
df.nsmallest(5, 'Cases_Property_Stolen')
# Out:
#      Crime_Year                  Area_Name  \
# 403        2002                Lakshadweep
# 418        2002                Uttarakhand
# 438        2003                Lakshadweep
# 453        2003                Uttarakhand
# 455        2004  Andaman & Nicobar Islands
#
#                               Group_Name               Sub_Group_Name  \
# 403  Criminal Breach of Trust - Property  5. Criminal Breach of Trust
# 418  Criminal Breach of Trust - Property  5. Criminal Breach of Trust
# 438  Criminal Breach of Trust - Property  5. Criminal Breach of Trust
# 453  Criminal Breach of Trust - Property  5. Criminal Breach of Trust
# 455  Criminal Breach of Trust - Property  5. Criminal Breach of Trust
#
#      Cases_Property_Recovered  Cases_Property_Stolen  \
# 403                         0                      0
# 418                         0                      0
# 438                         0                      0
# 453                         0                      0
# 455                         0                      0
#
#      Value_of_Property_Recovered  Value_of_Property_Stolen
# 403                            0                         0
# 418                            0                         0
# 438                            0                         0
# 453                            0                         0
# 455                            0                         0
